# %%
cd ..
# Out:
# c:\Users\dell\Desktop\major_project\project-final\Tourist-Attraction-Recommendation-System
# c:\Users\dell\Desktop\major_project\project-final\Tourist-Attraction-Recommendation-System\venvy\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd
import json
import csv

# %% [markdown]
# Convert json to csv

# %%
#converting json to csv

import json
import csv

# Input JSON file and output CSV file
input_file = 'C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/datareview1.json'
# Replace with your JSON file name
output_file = 'datareview1.csv'  # Desired output CSV file name

# Load JSON data
with open(input_file, 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# Ensure the data is a list of dictionaries
if not isinstance(data, list):
    data = [data]

# Extract headers from keys
headers = data[0].keys()

# Write to CSV
with open(output_file, 'w', encoding='utf-8', newline='') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=headers)
    writer.writeheader()

    # Write rows, handling nested structures (like photos) by converting them to strings
    for row in data:
        row['photos'] = ", ".join(row['photos']) if isinstance(row['photos'], list) else row['photos']
        writer.writerow(row)

print(f"JSON data successfully converted to {output_file}")
# Out:
# JSON data successfully converted to datareview1.csv

# %%
input_file = 'C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/datareview1.csv'
df=pd.read_csv(input_file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   place_name      4177 non-null   object
#  1   reviewer_name   4177 non-null   object
#  2   reviewer_link   4177 non-null   object
#  3   reviewer_image  4177 non-null   object
#  4   rating          4177 non-null   int64
#  5   date            4177 non-null   object
#  6   text            3408 non-null   object
#  7   photos          1731 non-null   object
#  8   likes_count     4177 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 293.8+ KB

# %% [markdown]
# CSV file combined

# %%
import pandas as pd

# List of file paths for the CSV files
file_paths = ['C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/reviews_box2.csv', 'C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/reviews_box3.csv']

# Read and combine all CSV files into a single DataFrame
combined_df = pd.concat([pd.read_csv(file) for file in file_paths], ignore_index=True)

# Add a unique 'reviewer_id' column
# Example: Using the index (1, 2, 3,...)
# combined_df['reviewer_id'] = combined_df.index + 1

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('reviews_box12.csv', index=False)

print("All files have been combined into 'reviews_box12' ")
# Out:
# All files have been combined into 'reviews_box12' with reviewer_id added.

# %%
input_file = 'C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/reviews_box12.csv'
df=pd.read_csv(input_file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   place_name      3023 non-null   object
#  1   reviewer_name   3023 non-null   object
#  2   reviewer_link   3023 non-null   object
#  3   reviewer_image  3023 non-null   object
#  4   rating          3023 non-null   int64
#  5   date            2903 non-null   object
#  6   text            2468 non-null   object
#  7   photos          1338 non-null   object
#  8   likes_count     3023 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 212.7+ KB

# %%
# Check for duplicate values in the 'user_name' column
duplicates = df['reviewer_name'].duplicated()

# Print the rows where 'user_name' is duplicated
duplicated_rows = df[duplicates]

# Show duplicated rows
print("Duplicated rows based on 'user_name':")
print(duplicated_rows)
# Out:
# Duplicated rows based on 'user_name':
#                                 place_name            reviewer_name  \
# 50                                 50 kilo          Sushil Maharjan
# 90                               Aane kuwa    Sushil Chandra Lamsal
# 119                       Agnishala Temple           Shivesh Sharma
# 165   Ancient Purenwa (Bilash kunj Durbar)               Aftab Alam
# 242                      Ibahi Thura stupa  Jenis “Jengiz Gemini” P
# ...                                    ...                      ...
# 2948                         Taragaon Next               Jivan Kala
# 2953                   Tengboche Monastery    Nickace Buzzlightyear
# 2955                   Tengboche Monastery                   Dr KAP
# 2984            Tripura Sundari Mai Temple         Santosh Shrestha
# 2986            Tripura Sundari Mai Temple             Sanjay Nepal
#
#                                           reviewer_link  \
# 50    https://www.google.com/maps/contrib/1113967697...
# 90    https://www.google.com/maps/contrib/1183522915...
# 119   https://www.google.com/maps/contrib/1004037295...
# 165   https://www.google.com/maps/contrib/1138862153...
# 242   https://www.google.com/maps/contrib/1050603436...
# ...                                                 ...
# 2948  https://www.google.com/maps/contrib/1066005640...
# 2953  https://www.google.com/maps/contrib/1055937092...
# 2955  https://www.google.com/maps/contrib/1047749993...
# 2984  https://www.google.com/maps/contrib/1074837329...
# 2986  https://www.google.com/maps/contrib/1094816779...
#
#                                          reviewer_image  rating          date  \
# 50    https://lh3.googleusercontent.com/a-/ALV-UjWnw...       5    a year ago
# 90    https://lh3.googleusercontent.com/a-/ALV-UjVAD...       5   3 years ago
# 119   https://lh3.googleusercontent.com/a-/ALV-UjX3T...       5   4 years ago
# 165   https://lh3.googleusercontent.com/a-/ALV-UjUCS...       1   5 years ago
# 242   https://lh3.googleusercontent.com/a-/ALV-UjXj9...       4  7 months ago
# ...                                                 ...     ...           ...
# 2948  https://lh3.googleusercontent.com/a-/ALV-UjXYh...       5  9 months ago
# 2953  https://lh3.googleusercontent.com/a-/ALV-UjVVX...       4    a week ago
# 2955  https://lh3.googleusercontent.com/a-/ALV-UjWKx...       5  6 months ago
# 2984  https://lh3.googleusercontent.com/a-/ALV-UjWHC...       5   a month ago
# 2986  https://lh3.googleusercontent.com/a-/ALV-UjUc_...       5   5 years ago
#
#                                                    text  \
# 50                                                  NaN
# 90                            Wonderful natural spring.
# 119   Agnishala is an ancient and a sacred place for...
# 165                                            Not good
# 242   Among four Thur of lalitpur this is one of  th...
# ...                                                 ...
# 2948  The Taragaon Museum is located in Kathmandu, N...
# 2953  Tengboche monastery in Solu Khumbu Nepal in ea...
# 2955  On EBC Trekk route monastery\nOn clearday can ...
# 2984  This place is very pleasant. The temple is bea...
# 2986  This is one of the major Religious Destination...
#
#                                                  photos  likes_count
# 50                                                  NaN            0
# 90                                                  NaN            0
# 119                                                 NaN            3
# 165                                                 NaN            0
# 242   https://lh5.googleusercontent.com/p/AF1QipP_uv...            4
# ...                                                 ...          ...
# 2948  https://lh5.googleusercontent.com/p/AF1QipN958...            0
# 2953  https://lh5.googleusercontent.com/p/AF1QipM5wP...            0
# 2955  https://lh5.googleusercontent.com/p/AF1QipMV7q...            0
# 2984                                                NaN            0
# 2986                                                NaN            4
#
# [357 rows x 9 columns]

# %% [markdown]
# Unique user id set

# %%
import pandas as pd

# Load the existing file
file_path = 'C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/reviews_box12.csv'
df = pd.read_csv(file_path)

# Check for duplicates in the 'user_name' column (Optional)
duplicates = df['reviewer_name'].duplicated()
duplicated_rows = df[duplicates]
print("Duplicated rows based on 'user_name':")
print(duplicated_rows)

# Assign same 'user_id' for each unique 'user_name'
df['user_id'] = pd.factorize(df['reviewer_name'])[0] + 1  # Adding 1 to start the user_id from 1

# Save the updated DataFrame to a new CSV file
output_file = 'reviwes_id.csv'
df.to_csv(output_file, index=False)

print(f"User IDs have been updated and saved as '{output_file}'.")
# Out:
# Duplicated rows based on 'user_name':
#                                 place_name            reviewer_name  \
# 50                                 50 kilo          Sushil Maharjan
# 90                               Aane kuwa    Sushil Chandra Lamsal
# 119                       Agnishala Temple           Shivesh Sharma
# 165   Ancient Purenwa (Bilash kunj Durbar)               Aftab Alam
# 242                      Ibahi Thura stupa  Jenis “Jengiz Gemini” P
# ...                                    ...                      ...
# 2948                         Taragaon Next               Jivan Kala
# 2953                   Tengboche Monastery    Nickace Buzzlightyear
# 2955                   Tengboche Monastery                   Dr KAP
# 2984            Tripura Sundari Mai Temple         Santosh Shrestha
# 2986            Tripura Sundari Mai Temple             Sanjay Nepal
#
#                                           reviewer_link  \
# 50    https://www.google.com/maps/contrib/1113967697...
# 90    https://www.google.com/maps/contrib/1183522915...
# 119   https://www.google.com/maps/contrib/1004037295...
# 165   https://www.google.com/maps/contrib/1138862153...
# 242   https://www.google.com/maps/contrib/1050603436...
# ...                                                 ...
# 2948  https://www.google.com/maps/contrib/1066005640...
# 2953  https://www.google.com/maps/contrib/1055937092...
# 2955  https://www.google.com/maps/contrib/1047749993...
# 2984  https://www.google.com/maps/contrib/1074837329...
# 2986  https://www.google.com/maps/contrib/1094816779...
#
#                                          reviewer_image  rating          date  \
# 50    https://lh3.googleusercontent.com/a-/ALV-UjWnw...       5    a year ago
# 90    https://lh3.googleusercontent.com/a-/ALV-UjVAD...       5   3 years ago
# 119   https://lh3.googleusercontent.com/a-/ALV-UjX3T...       5   4 years ago
# 165   https://lh3.googleusercontent.com/a-/ALV-UjUCS...       1   5 years ago
# 242   https://lh3.googleusercontent.com/a-/ALV-UjXj9...       4  7 months ago
# ...                                                 ...     ...           ...
# 2948  https://lh3.googleusercontent.com/a-/ALV-UjXYh...       5  9 months ago
# 2953  https://lh3.googleusercontent.com/a-/ALV-UjVVX...       4    a week ago
# 2955  https://lh3.googleusercontent.com/a-/ALV-UjWKx...       5  6 months ago
# 2984  https://lh3.googleusercontent.com/a-/ALV-UjWHC...       5   a month ago
# 2986  https://lh3.googleusercontent.com/a-/ALV-UjUc_...       5   5 years ago
#
#                                                    text  \
# 50                                                  NaN
# 90                            Wonderful natural spring.
# 119   Agnishala is an ancient and a sacred place for...
# 165                                            Not good
# 242   Among four Thur of lalitpur this is one of  th...
# ...                                                 ...
# 2948  The Taragaon Museum is located in Kathmandu, N...
# 2953  Tengboche monastery in Solu Khumbu Nepal in ea...
# 2955  On EBC Trekk route monastery\nOn clearday can ...
# 2984  This place is very pleasant. The temple is bea...
# 2986  This is one of the major Religious Destination...
#
#                                                  photos  likes_count
# 50                                                  NaN            0
# 90                                                  NaN            0
# 119                                                 NaN            3
# 165                                                 NaN            0
# 242   https://lh5.googleusercontent.com/p/AF1QipP_uv...            4
# ...                                                 ...          ...
# 2948  https://lh5.googleusercontent.com/p/AF1QipN958...            0
# 2953  https://lh5.googleusercontent.com/p/AF1QipM5wP...            0
# 2955  https://lh5.googleusercontent.com/p/AF1QipMV7q...            0
# 2984                                                NaN            0
# 2986                                                NaN            4
#
# [357 rows x 9 columns]
# User IDs have been updated and saved as 'reviwes_id.csv'.

# %%
import pandas as pd

# Load the existing file
file_path = 'C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/user.csv'
df = pd.read_csv(file_path)

# Rename columns
df.rename(columns={

    # 'reviewer_name': 'user_name',
    # 'text': 'review_text,'
    'place_name': 'name'
}, inplace=True)

# Rearrange columns in the desired order
rearranged_columns = ['user_id', 'user_name','name', 'rating', 'review_text', 'date', 'likes_count', 
                      'reviewer_link', 'reviewer_image', 'photos']
df = df[rearranged_columns]

# Save the updated DataFrame to a new CSV file
output_file = 'users.csv'
df.to_csv(output_file, index=False)

print(f"Columns have been renamed and rearranged. The updated file is saved as '{output_file}'.")
# Out:
# Columns have been renamed and rearranged. The updated file is saved as 'users.csv'.

# %%
import pandas as pd

# Step 1: Load the existing CSV file
file_path = 'C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Web Scraping/user.csv'
df = pd.read_csv(file_path)

# Step 2: Find duplicated user names and show their corresponding user_ids
duplicated_names = df[df.duplicated('user_name', keep=False)]  # Keep=False to show all duplicates

# Step 3: Display the duplicated 'user_name' along with 'user_id'
if not duplicated_names.empty:
    print("Duplicated 'user_name' with corresponding 'user_id':")
    print(duplicated_names[['user_name', 'user_id']])
else:
    print("No duplicated 'user_name' found.")
# Out:
# Duplicated 'user_name' with corresponding 'user_id':
#                      user_name  user_id
# 0               Shivesh Sharma        1
# 1             Shakti Man Singh        2
# 2              Rupesh Maharjan        3
# 8     Hestiabelle Zannillestel        9
# 9              Ravindu Hasanka       10
# ...                        ...      ...
# 2948                Jivan Kala      954
# 2953     Nickace Buzzlightyear       82
# 2955                    Dr KAP     2435
# 2984          Santosh Shrestha     2212
# 2986              Sanjay Nepal     2263
#
# [605 rows x 2 columns]

# %%
# Check for duplicate values in the 'user_name' column
duplicates = df['user_name'].duplicated()

# Print the rows where 'user_name' is duplicated
duplicated_rows = df[duplicates]

# Show duplicated rows
print("Duplicated rows based on 'user_name':")
print(duplicated_rows)
# Out:
# Duplicated rows based on 'user_name':
#       user_id                user_name                            place_name  \
# 50         50          Sushil Maharjan                               50 kilo
# 90         19    Sushil Chandra Lamsal                             Aane kuwa
# 119         1           Shivesh Sharma                      Agnishala Temple
# 165       161               Aftab Alam  Ancient Purenwa (Bilash kunj Durbar)
# 242       116  Jenis “Jengiz Gemini” P                     Ibahi Thura stupa
# ...       ...                      ...                                   ...
# 2948      954               Jivan Kala                         Taragaon Next
# 2953       82    Nickace Buzzlightyear                   Tengboche Monastery
# 2955     2435                   Dr KAP                   Tengboche Monastery
# 2984     2212         Santosh Shrestha            Tripura Sundari Mai Temple
# 2986     2263             Sanjay Nepal            Tripura Sundari Mai Temple
#
#       rating                                        review_text          date  \
# 50         5                                                NaN    a year ago
# 90         5                          Wonderful natural spring.   3 years ago
# 119        5  Agnishala is an ancient and a sacred place for...   4 years ago
# 165        1                                           Not good   5 years ago
# 242        4  Among four Thur of lalitpur this is one of  th...  7 months ago
# ...      ...                                                ...           ...
# 2948       5  The Taragaon Museum is located in Kathmandu, N...  9 months ago
# 2953       4  Tengboche monastery in Solu Khumbu Nepal in ea...    a week ago
# 2955       5  On EBC Trekk route monastery\nOn clearday can ...  6 months ago
# 2984       5  This place is very pleasant. The temple is bea...   a month ago
# 2986       5  This is one of the major Religious Destination...   5 years ago
#
#       likes_count                                      reviewer_link  \
# 50              0  https://www.google.com/maps/contrib/1113967697...
# 90              0  https://www.google.com/maps/contrib/1183522915...
# 119             3  https://www.google.com/maps/contrib/1004037295...
# 165             0  https://www.google.com/maps/contrib/1138862153...
# 242             4  https://www.google.com/maps/contrib/1050603436...
# ...           ...                                                ...
# 2948            0  https://www.google.com/maps/contrib/1066005640...
# 2953            0  https://www.google.com/maps/contrib/1055937092...
# 2955            0  https://www.google.com/maps/contrib/1047749993...
# 2984            0  https://www.google.com/maps/contrib/1074837329...
# 2986            4  https://www.google.com/maps/contrib/1094816779...
#
#                                          reviewer_image  \
# 50    https://lh3.googleusercontent.com/a-/ALV-UjWnw...
# 90    https://lh3.googleusercontent.com/a-/ALV-UjVAD...
# 119   https://lh3.googleusercontent.com/a-/ALV-UjX3T...
# 165   https://lh3.googleusercontent.com/a-/ALV-UjUCS...
# 242   https://lh3.googleusercontent.com/a-/ALV-UjXj9...
# ...                                                 ...
# 2948  https://lh3.googleusercontent.com/a-/ALV-UjXYh...
# 2953  https://lh3.googleusercontent.com/a-/ALV-UjVVX...
# 2955  https://lh3.googleusercontent.com/a-/ALV-UjWKx...
# 2984  https://lh3.googleusercontent.com/a-/ALV-UjWHC...
# 2986  https://lh3.googleusercontent.com/a-/ALV-UjUc_...
#
#                                                  photos
# 50                                                  NaN
# 90                                                  NaN
# 119                                                 NaN
# 165                                                 NaN
# 242   https://lh5.googleusercontent.com/p/AF1QipP_uv...
# ...                                                 ...
# 2948  https://lh5.googleusercontent.com/p/AF1QipN958...
# 2953  https://lh5.googleusercontent.com/p/AF1QipM5wP...
# 2955  https://lh5.googleusercontent.com/p/AF1QipMV7q...
# 2984                                                NaN
# 2986                                                NaN
#
# [357 rows x 10 columns]

# %% [markdown]
# Userid,placeid,rating

# %%
import pandas as pd
from rapidfuzz import fuzz, process

# Load the CSV files
file1="C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Data/FinalDataset/users.csv"  # CSV containing user id, user name, name, rating
file2 = "C:/Users/dell/Desktop/major_project/project-final/Tourist-Attraction-Recommendation-System/Data/FinalDataset/Data.csv"  # CSV containing id, name



# Read the CSV files
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Debug: Check columns in File 1 and File 2
print("File 1 columns:", df1.columns)
print("File 2 columns:", df2.columns)

# Clean column names to avoid hidden issues (e.g., extra spaces or casing mismatches)
df1.columns = df1.columns.str.strip().str.lower()
df2.columns = df2.columns.str.strip().str.lower()

# # Merge the DataFrames on 'place_name' from File 1 and 'name' from File 2
# merged_df = pd.merge(df1, df2, left_on='place_name', right_on='name', how='left')

# Specify the columns to compare
column1 = df1['name']  # Replace with the actual column name in file1
column2 = df2['name']  # Replace with the actual column name in file2


# # Define a function for fuzzy matching
# def match_places(place, choices, threshold=80):
#     # Find the best match
#     match, score, _ = process.extractOne(place, choices, scorer=fuzz.partial_ratio)
#     if score >= threshold:
#         return match  # Return the matched place if the score exceeds the threshold
#     return None

# # Perform fuzzy matching
# df1['matched_place'] = df1['place_name'].apply(lambda x: match_places(x, column2))

# Define a function to check if the first 10 letters match
def match_first_13_letters(place, choices):
    for choice in choices:
        if place[:13].lower() == choice[:13].lower():  # Compare first 10 characters (case insensitive)
            return choice  # Return the matched place
    return None

# Perform matching
df1['matched_place'] = df1['name'].apply(lambda x: match_first_13_letters(x, column2))


# Merge the two dataframes on the matched place name
merged_df = pd.merge(df1, df2, left_on='matched_place', right_on='name', how='inner')


# Debug: Check columns in merged DataFrame
print("Columns in merged DataFrame:", merged_df.columns)

# Select the required columns
try:
    result_df = merged_df[['user_id', 'id','rating']]  # Adjust names based on debugging
    # result_df.rename(columns={'id': 'place_id'}, inplace=True)
    # result_df.rename(columns={'rating_x': 'rating'}, inplace=True)
    # result_df.rename(columns={'name_x': 'name_user'}, inplace=True)
    # result_df.rename(columns={'name_y': 'name_places'}, inplace=True)

    # Save the result to a new CSV file
    result_df.to_csv("ratings.csv", index=False)
    print("New CSV file created: ratings.csv")
except KeyError as e:
    print("KeyError:", e)
    print("Available columns in merged DataFrame:", merged_df.columns)
# Out:
# File 1 columns: Index(['user_id', 'user_name', 'name', 'rating', 'review_text', 'date',
#        'likes_count', 'reviewer_link', 'reviewer_image', 'photos'],
#       dtype='object')
# File 2 columns: Index(['id', 'name', 'description', 'latitude', 'longitude', 'province',
#        'location', 'tags'],
#       dtype='object')
# Columns in merged DataFrame: Index(['user_id', 'user_name', 'name_x', 'rating', 'review_text', 'date',
#        'likes_count', 'reviewer_link', 'reviewer_image', 'photos',
#        'matched_place', 'id', 'name_y', 'description', 'latitude', 'longitude',
#        'province', 'location', 'tags'],
#       dtype='object')
# New CSV file created: ratings.csv

# %%
output_df = pd.read_csv('user_place_id_rating.csv')
print("Null values in output.csv:")
print(output_df.isnull().sum())
# Out:
# Null values in output.csv:
# user_id        0
# place_id    1180
# rating         0
# dtype: int64
