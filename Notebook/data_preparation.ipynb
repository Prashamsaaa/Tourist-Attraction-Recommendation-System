# %% [markdown]
# IMPORTING NECESSARY LIBRARIES

# %%
import pandas as pd
import string
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Download required NLTK data
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sussh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sussh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv("../Data/FinalDataset/Data.csv")
df.head()
# Out:
#    id                               name  \
# 0   1               Chapat Ganesh Mandir
# 1   3                      Sikali Mandir
# 2   5           21st Century Art Gallery
# 3   6  3D Art World - Interactive Museum
# 4   7                   Nyatapola Temple
#
#                                          description   latitude  longitude  \
# 0  Chapat Ganesh Temple is Ganesh temple located ...  27.671314  85.328967
# 1  Religious Site Sikali Temple lies in the south...  27.643535  85.285502
# 2  21st Century Art Gallery, located in Kathmandu...  27.715548  85.309497
# 3  The 3D Fun Art Museum is a unique and interact...  27.651018  85.344114
# 4  Nyatapola Temple, located in Bhaktapur, Nepal,...  27.671081  85.429302
#
#            province          location                           tags
# 0  Bagmati Province  Bagmati Province      hindu, temple, pilgrimage
# 1  Bagmati Province  Kathmandu Valley        hindu, temple, cultural
# 2  Bagmati Province         Kathmandu  art_gallery, museum, cultural
# 3  Bagmati Province      Mahalakshmai                         museum
# 4  Bagmati Province         Bhaktapur    hindu, historical, cultural

# %%
selected_columns = ['id', 'name', 'description', 'province', 'tags']
dataset = df[selected_columns]
dataset.columns = ['ID', 'Name', 'Description', 'Province', 'Tags']
dataset.head()
# Out:
#    ID                               Name  \
# 0   1               Chapat Ganesh Mandir
# 1   3                      Sikali Mandir
# 2   5           21st Century Art Gallery
# 3   6  3D Art World - Interactive Museum
# 4   7                   Nyatapola Temple
#
#                                          Description          Province  \
# 0  Chapat Ganesh Temple is Ganesh temple located ...  Bagmati Province
# 1  Religious Site Sikali Temple lies in the south...  Bagmati Province
# 2  21st Century Art Gallery, located in Kathmandu...  Bagmati Province
# 3  The 3D Fun Art Museum is a unique and interact...  Bagmati Province
# 4  Nyatapola Temple, located in Bhaktapur, Nepal,...  Bagmati Province
#
#                             Tags
# 0      hindu, temple, pilgrimage
# 1        hindu, temple, cultural
# 2  art_gallery, museum, cultural
# 3                         museum
# 4    hindu, historical, cultural

# %% [markdown]
# CLEAN AND NORMALIZE TEXT

# %%
def clean_text(text):
    if pd.isnull(text):
        return text 
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Tokenize text
    tokens = word_tokenize(text)
    # Lemmatize tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    # Join tokens back to string
    return ' '.join(tokens)

dataset['Description'] = dataset['Description'].apply(clean_text)
dataset['Tags'] = dataset['Tags'].apply(clean_text)

dataset.head()
# Out:
# C:\Users\sussh\AppData\Local\Temp\ipykernel_11096\3143449311.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Description'] = dataset['Description'].apply(clean_text)
# C:\Users\sussh\AppData\Local\Temp\ipykernel_11096\3143449311.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Tags'] = dataset['Tags'].apply(clean_text)
#    ID                               Name  \
# 0   1               Chapat Ganesh Mandir
# 1   3                      Sikali Mandir
# 2   5           21st Century Art Gallery
# 3   6  3D Art World - Interactive Museum
# 4   7                   Nyatapola Temple
#
#                                          Description          Province  \
# 0  chapat ganesh temple is ganesh temple located ...  Bagmati Province
# 1  religious site sikali temple lie in the southe...  Bagmati Province
# 2  21st century art gallery located in kathmandu ...  Bagmati Province
# 3  the 3d fun art museum is a unique and interact...  Bagmati Province
# 4  nyatapola temple located in bhaktapur nepal is...  Bagmati Province
#
#                          Tags
# 0     hindu temple pilgrimage
# 1       hindu temple cultural
# 2  artgallery museum cultural
# 3                      museum
# 4   hindu historical cultural

# %% [markdown]
# CHECK FOR MISSING VALUES

# %%
missing_value_rows = dataset[dataset.isnull().any(axis=1)]

# Display the IDs of rows with missing values
if 'ID' in missing_value_rows.columns:
    print("IDs of rows with missing values:")
    print(missing_value_rows['ID'].tolist())
else:
    print("The 'ID' column is not present in the dataset.")
# Out:
# IDs of rows with missing values:
# []

# %% [markdown]
# FINAL CHECK

# %%
print("Dataset Info:")
print(dataset.info())

print("\nSample Rows:")
print(dataset.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1859 entries, 0 to 1858
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1859 non-null   int64
#  1   Name         1859 non-null   object
#  2   Description  1859 non-null   object
#  3   Province     1859 non-null   object
#  4   Tags         1859 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 72.7+ KB
# None
#
# Sample Rows:
#    ID                               Name  \
# 0   1               Chapat Ganesh Mandir
# 1   3                      Sikali Mandir
# 2   5           21st Century Art Gallery
# 3   6  3D Art World - Interactive Museum
# 4   7                   Nyatapola Temple
#
#                                          Description          Province  \
# 0  chapat ganesh temple is ganesh temple located ...  Bagmati Province
# 1  religious site sikali temple lie in the southe...  Bagmati Province
# 2  21st century art gallery located in kathmandu ...  Bagmati Province
# 3  the 3d fun art museum is a unique and interact...  Bagmati Province
# 4  nyatapola temple located in bhaktapur nepal is...  Bagmati Province
#
#                          Tags
# 0     hindu temple pilgrimage
# 1       hindu temple cultural
# 2  artgallery museum cultural
# 3                      museum
# 4   hindu historical cultural

# %%
dataset.to_csv("Output/PreparedData.csv", index=False)
